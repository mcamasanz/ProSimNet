# %%
import sys, os
import numpy as np
from pprint import pprint


ruta_libs = os.path.abspath("../libs")
if ruta_libs not in sys.path:
    sys.path.append(ruta_libs)

from materialLibs import *
from unitsLibs import *
from solveLibs import *

# %%
species = ["CO2", "N2"]
WM, mu, Dm, cpg_molar, cpg_mass, k, H = get_properties_gas(species)
propiedades_gas = {
    "species": species,
    "MW": WM,
    "mu": mu,
    "Dm": Dm,
    "Cp_molar": cpg_molar,
    "Cp_mass": cpg_mass,
    "k": k,
    "H": H}

# %%
sim=ProSimNet()
# Out:
# 🧠 ProSimNet inicializado 📅 Día: 2025-07-29 ⏰ Hora: 09:18:48

# %%
tank_1 = Tank(
    Name="T1",
    Longitud=2.0,     # m
    Diametro=.61,     # m
    Espesor=0.02,     # m
    prop_gas=propiedades_gas)

vT1bi = Valve(
    Name="vT1bi",
    Cv_max= 1.35,  
    valve_type="linear",
    a_min = 0.,
    a_max = 1.,
    logic= "linear",
    logic_params={"start": 1, "duration": 15},
    opening_direction="co")

vT1to = Valve(
    Name="vT1to",
    Cv_max= 1.35,  
    valve_type="linear",
    a_min = 0.,
    a_max = 1.,
    logic= "linear",
    logic_params={"start": 1, "duration": 15},
    opening_direction="co")

tank_2 = Tank(
    Name="T2",
    Longitud=2.0,     # m
    Diametro=.61,     # m
    Espesor=0.02,     # m
    prop_gas=propiedades_gas)

vT2bi = Valve(
    Name="vT2bi",
    Cv_max= 1.35,  
    valve_type="linear",
    a_min = 0.,
    a_max = 1.,
    logic= "linear",
    logic_params={"start": 1, "duration": 15},
    opening_direction="co")

vT2to = Valve(
    Name="vT2bo",
    Cv_max= 1.35,  
    valve_type="linear",
    a_min = 0.,
    a_max = 1.,
    logic= "linear",
    logic_params={"start": 1, "duration": 15},
    opening_direction="co")

tank_3 = Tank(
    Name="T3",
    Longitud=2.0,     # m
    Diametro=.61,     # m
    Espesor=0.02,     # m
    prop_gas=propiedades_gas)

vT1bT2b = Valve(
    Name="vT1bT2b",
    Cv_max= 1.35,  
    valve_type="linear",
    a_min = 0.,
    a_max = 1.,
    logic= "linear",
    logic_params={"start": 1, "duration": 15},
    opening_direction="co")

vT1tT2t = Valve(
    Name="vT1tT2t",
    Cv_max= 1.35,  
    valve_type="linear",
    a_min = 0.,
    a_max = 1.,
    logic= "linear",
    logic_params={"start": 1, "duration": 15},
    opening_direction="co")

valves=[vT1bi,vT1to,vT2bi,vT2to,vT1tT2t,vT1bT2b]
tanks=[tank_1,tank_2,]
sim.addUnits(tanks)
sim.addValves(valves)

# %%
sim.updateNetwork()

# %%
for i in range(0,len(sim.Units)):
    print(sim.Units[i]._name)
    print(sim.Units[i]._conex)
# Out:
# T1
# {'inlet': 'vT1bi', 'where_inlet': 'bottom', 'outlet': 'vT1bo', 'where_outlet': 'bottom', 'valves_top': ['vT1tT2t'], 'valves_bottom': ['vT1bT2b'], 'valves_side': [], 'units_top': ['T2'], 'units_bottom': ['T2'], 'unitss_side': []}
# T2
# {'inlet': 'vT2bi', 'where_inlet': 'bottom', 'outlet': 'vT2bo', 'where_outlet': 'bottom', 'valves_top': ['vT1tT2t'], 'valves_bottom': ['vT1bT2b'], 'valves_side': [], 'units_top': ['T1'], 'units_bottom': ['T1'], 'unitss_side': []}

# %%
for i in range(0,len(sim.Valves)):
    print(sim.Valves[i]._name)
    print(sim.Valves[i]._conex)
# Out:
# vT1bi
# {'type': 'inlet', 'unit_A': 'T1', 'unit_B': None, 'port_A': 'bottom', 'port_B': None}
# vT1bo
# {'type': 'outlet', 'unit_A': 'T1', 'unit_B': None, 'port_A': 'bottom', 'port_B': None}
# vT2bi
# {'type': 'inlet', 'unit_A': 'T2', 'unit_B': None, 'port_A': 'bottom', 'port_B': None}
# vT2bo
# {'type': 'outlet', 'unit_A': 'T2', 'unit_B': None, 'port_A': 'bottom', 'port_B': None}
# vT1tT2t
# {'type': 'interunit', 'unit_A': 'T1', 'unit_B': 'T2', 'port_A': 'top', 'port_B': 'top'}
# vT1bT2b
# {'type': 'interunit', 'unit_A': 'T1', 'unit_B': 'T2', 'port_A': 'bottom', 'port_B': 'bottom'}

# %%
sim.Networks
# Out:
# [{'valve': 'vT1bi',
#   'type': 'inlet',
#   'unit_A': 'T1',
#   'port_A': 'bottom',
#   'unit_B': None,
#   'port_B': None},
#  {'valve': 'vT1bo',
#   'type': 'outlet',
#   'unit_A': 'T1',
#   'port_A': 'bottom',
#   'unit_B': None,
#   'port_B': None},
#  {'valve': 'vT2bi',
#   'type': 'inlet',
#   'unit_A': 'T2',
#   'port_A': 'bottom',
#   'unit_B': None,
#   'port_B': None},
#  {'valve': 'vT2bo',
#   'type': 'outlet',
#   'unit_A': 'T2',
#   'port_A': 'bottom',
#   'unit_B': None,
#   'port_B': None},
#  {'valve': 'vT1tT2t',
#   'type': 'interunit',
#   'unit_A': 'T1',
#   'port_A': 'top',
#   'unit_B': 'T2',
#   'port_B': 'top'},
#  {'valve': 'vT1bT2b',
#   'type': 'interunit',
#   'unit_A': 'T1',
#   'port_A': 'bottom',
#   'unit_B': 'T2',
#   'port_B': 'bottom'}]
