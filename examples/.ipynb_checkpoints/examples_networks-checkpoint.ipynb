# %%
import sys, os
import numpy as np
from pprint import pprint


ruta_libs = os.path.abspath("../libs")
if ruta_libs not in sys.path:
    sys.path.append(ruta_libs)

from materialLibs import *
from unitsLibs import *
from solveLibs import *
from networkLibs import *

# %%
species = ["CO2", "N2"]
WM, mu, Dm, cpg_molar, cpg_mass, k, H = get_properties_gas(species)
prop_gas = {
    "species": species,
    "MW": WM,
    "mu": mu,
    "Dm": Dm,
    "Cp_molar": cpg_molar,
    "Cp_mass": cpg_mass,
    "k": k,
    "H": H}

# %%
tank_1 = Tank(
    Name="T1",
    Longitud=2.0,     # m
    Diametro=.61,     # m
    Espesor=0.02,     # m
    prop_gas=prop_gas)

tank_1.initialC_info(P0=3.5e5,T0=298.0,x0=[0.5, 0.5])

tank_1.boundaryC_info(Pin=9e5,Tin=350.0,xin=[0.2, 0.8],Pout=1e5)

tank_1.thermal_info(adi=True,kw=1e99,hint=1e99,hext=1e99,Tamb=298.15)

vT1bi = Valve(
    Name="vT1bi",
    Cv_max= 1.35,  
    valve_type="linear",
    a_min = 0.,
    a_max = 1.,
    logic= "linear",
    logic_params={"start": 1, "duration": 15},
    opening_direction="co")

vT1to = Valve(
    Name="vT1to",
    Cv_max= 1.35,  
    valve_type="linear",
    a_min = 0.,
    a_max = 1.,
    logic= "linear",
    logic_params={"start": 1, "duration": 15},
    opening_direction="co")

tank_2 = Tank(
    Name="T2",
    Longitud=2.0,     # m
    Diametro=.61,     # m
    Espesor=0.02,     # m
    prop_gas=prop_gas)

tank_2.initialC_info(P0=3.5e5,T0=298.0,x0=[0.5, 0.5])

tank_2.boundaryC_info(Pin=9e5,Tin=350.0,xin=[0.2, 0.8],Pout=1e5)

tank_2.thermal_info(adi=True,kw=1e99,hint=1e99,hext=1e99,Tamb=298.15)

vT2bi = Valve(
    Name="vT2bi",
    Cv_max= 1.35,  
    valve_type="linear",
    a_min = 0.,
    a_max = 1.,
    logic= "linear",
    logic_params={"start": 1, "duration": 15},
    opening_direction="co")

vT2to = Valve(
    Name="vT2to",
    Cv_max= 1.35,  
    valve_type="linear",
    a_min = 0.,
    a_max = 1.,
    logic= "linear",
    logic_params={"start": 1, "duration": 15},
    opening_direction="co")

vT1bT2b = Valve(
    Name="vT1bT2b",
    Cv_max= 1.35,  
    valve_type="linear",
    a_min = 0.,
    a_max = 1.,
    logic= "linear",
    logic_params={"start": 1, "duration": 15},
    opening_direction="co")

vT1tT2t = Valve(
    Name="vT1tT2t",
    Cv_max= 1.35,  
    valve_type="linear",
    a_min = 0.,
    a_max = 1.,
    logic= "linear",
    logic_params={"start": 1, "duration": 15},
    opening_direction="co")

valves=[vT1bi,vT1to,vT2bi,vT2to,vT1tT2t,vT1bT2b]
units=[tank_1,tank_2,]

# %%
sim=Network(prop_gas=prop_gas,
            Units=units,
            Valves=valves)
# Out:
# 🧠 ProSimNet inicializado 📅 Día: 2025-07-30 ⏰ Hora: 03:16:42

# %%
sim._updateNetwork()
sim._printNetwork()
# Out:
# === CONEXIONES DE UNIDADES ===
# Unidad: T1
# {'inlet': 'vT1bi', 'where_inlet': 'bottom', 'outlet': 'vT1to', 'where_outlet': 'top', 'valves_top': ['vT1tT2t'], 'valves_bottom': ['vT1bT2b'], 'valves_side': [], 'units_top': ['T2'], 'units_bottom': ['T2'], 'units_side': []}
#
# Unidad: T2
# {'inlet': 'vT2bi', 'where_inlet': 'bottom', 'outlet': 'vT2to', 'where_outlet': 'top', 'valves_top': ['vT1tT2t'], 'valves_bottom': ['vT1bT2b'], 'valves_side': [], 'units_top': ['T1'], 'units_bottom': ['T1'], 'units_side': []}
#
# === CONEXIONES DE VÁLVULAS ===
# Válvula: vT1bi
# {'type': 'inlet', 'unit_A': 'T1', 'unit_B': None, 'port_A': 'bottom', 'port_B': None}
#
# Válvula: vT1to
# {'type': 'outlet', 'unit_A': 'T1', 'unit_B': None, 'port_A': 'top', 'port_B': None}
#
# Válvula: vT2bi
# {'type': 'inlet', 'unit_A': 'T2', 'unit_B': None, 'port_A': 'bottom', 'port_B': None}
#
# Válvula: vT2to
# {'type': 'outlet', 'unit_A': 'T2', 'unit_B': None, 'port_A': 'top', 'port_B': None}
#
# Válvula: vT1tT2t
# {'type': 'interunit', 'unit_A': 'T1', 'unit_B': 'T2', 'port_A': 'top', 'port_B': 'top'}
#
# Válvula: vT1bT2b
# {'type': 'interunit', 'unit_A': 'T1', 'unit_B': 'T2', 'port_A': 'bottom', 'port_B': 'bottom'}
#
# === CONEXIONES DE LA RED (self.Networks) ===
# {'valve': 'vT1bi', 'type': 'inlet', 'unit_A': 'T1', 'port_A': 'bottom', 'unit_B': None, 'port_B': None}
# {'valve': 'vT1to', 'type': 'outlet', 'unit_A': 'T1', 'port_A': 'top', 'unit_B': None, 'port_B': None}
# {'valve': 'vT2bi', 'type': 'inlet', 'unit_A': 'T2', 'port_A': 'bottom', 'unit_B': None, 'port_B': None}
# {'valve': 'vT2to', 'type': 'outlet', 'unit_A': 'T2', 'port_A': 'top', 'unit_B': None, 'port_B': None}
# {'valve': 'vT1tT2t', 'type': 'interunit', 'unit_A': 'T1', 'port_A': 'top', 'unit_B': 'T2', 'port_B': 'top'}
# {'valve': 'vT1bT2b', 'type': 'interunit', 'unit_A': 'T1', 'port_A': 'bottom', 'unit_B': 'T2', 'port_B': 'bottom'}

# %% [markdown]
# ### anidamientos de objetos con las conexiones entre valvulas y units

# %%
print(sim.Units[0]._name+'\n')
print(sim.Units[0]._conex)
print(sim.Units[0]._conex['inlet']._name)
sim.Units[0]._conex['inlet']._conex['unit_A']._conex['inlet']._conex['unit_A']
# Out:
# T1
#
# {'inlet': <unitsLibs.Valve object at 0x000001FF36FFC310>, 'where_inlet': 'bottom', 'outlet': <unitsLibs.Valve object at 0x000001FF3724DA10>, 'where_outlet': 'top', 'valves_top': [<unitsLibs.Valve object at 0x000001FF38CC7650>], 'valves_bottom': [<unitsLibs.Valve object at 0x000001FF38CC72D0>], 'valves_side': [], 'units_top': [<unitsLibs.Tank object at 0x000001FF38CC6B90>], 'units_bottom': [<unitsLibs.Tank object at 0x000001FF38CC6B90>], 'units_side': []}
# vT1bi

# %%
sim._state_mapping
# Out:
# [(<unitsLibs.Tank at 0x1ff38cc6290>, 0, 3, ['N', 'x0', 'T']),
#  (<unitsLibs.Tank at 0x1ff38cc6b90>, 3, 6, ['N', 'x0', 'T'])]

# %%
sim._state_labels
# Out:
# {0: (<unitsLibs.Tank at 0x1ff38cc6290>, 'N'),
#  1: (<unitsLibs.Tank at 0x1ff38cc6290>, 'x0'),
#  2: (<unitsLibs.Tank at 0x1ff38cc6290>, 'T'),
#  3: (<unitsLibs.Tank at 0x1ff38cc6b90>, 'N'),
#  4: (<unitsLibs.Tank at 0x1ff38cc6b90>, 'x0'),
#  5: (<unitsLibs.Tank at 0x1ff38cc6b90>, 'T')}

# %%
y=np.zeros(sim._state_n_vars)
for idx, (unit, label) in sim._state_labels.items():
    if unit._name == "T1" and label == "N":
        print(f"La variable N del tanque T1 está en el índice global {idx}")
        
for (unit, i_ini, i_fin, labels) in sim._state_mapping:
    print(f"Equipo: {unit._name}, índice: {i_ini}:{i_fin}, variables: {labels}")
    # y puedes extraer el estado local así:
    estado_local = y[i_ini:i_fin]
# Out:
# La variable N del tanque T1 está en el índice global 0
# Equipo: T1, índice: 0:3, variables: ['N', 'x0', 'T']
# Equipo: T2, índice: 3:6, variables: ['N', 'x0', 'T']

# %%
sim._initialize()
sim._solve()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 sim._initialize()
# ----> 2 sim._solve()
#
# File ~\OneDrive - Fundacion CIRCE\Escritorio\github\ProSimNet\libs\networkLibs.py:305, in Network._solve(self)
#     303 y0 = np.zeros(self._state_n_vars)
#     304 for (unit, i_ini, i_fin, labels) in self._state_mapping:
# --> 305     y0[i_ini:i_fin] = unit._get_State()
#     306     print(y0)
#     308 return None
#
# File ~\OneDrive - Fundacion CIRCE\Escritorio\github\ProSimNet\libs\unitsLibs.py:486, in Tank._get_State(self)
#     485 def _get_State(self,):
# --> 486     yi = np.concatenate((
#     487         [self._state_vars["N"]],
#     488         self._state_vars["x"],
#     489         [self._state_vars["T"]]
#     490     ))
#     492     return yi
#
# File <__array_function__ internals>:200, in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 0 dimension(s)

# %%
tank_1._state_vars
# Out:
# {'t': 0.0, 'P': None, 'T': None, 'x': None, 'N': None}
